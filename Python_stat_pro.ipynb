# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашняя работа №4

# %% [markdown]
# # Виды распределений

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns
import statistics
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# **Задача:** нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %% [markdown]
# **Небольшое пояснение**: виды распределений (прописаны в названии графика) определяются визуально без последующих тестирований и проверок гипотез. Если в названии не указано распределение, значит из-за большого количества локальных экстремумов определить вид на глаз затруднительно.

# %%
ax = data['CRIM'].hist(bins=20)

ax.set_xlabel('CRIM')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра CRIM (экспоненциальное распределение)')
plt.grid(True)
plt.show()

# %%
ax = data['ZN'].hist(bins=15)

ax.set_xlabel('ZN')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра ZN')
plt.grid(True)
plt.show()

# %%
ax = data['INDUS'].hist(bins=50)

ax.set_xlabel('INDUS')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра INDUS')
plt.grid(True)
plt.show()

# %%
ax = data['CHAS'].hist(bins=10)

ax.set_xlabel('CHAS')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра CHAS (распределение Бернулли)')
plt.grid(True)
plt.show()

# %%
ax = data['NOX'].hist(bins=15)

ax.set_xlabel('NOX')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра NOX')
plt.grid(True)
plt.show()

# %%
ax = data['RM'].hist(bins=20)

ax.set_xlabel('RM')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра RM (расределение Стьюдента со смещением вправо)')
plt.grid(True)
plt.show()

# %%
ax = data['AGE'].hist(bins=20)

ax.set_xlabel('AGE')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра AGE (обратно экспоненциальное распределение)')
plt.grid(True)
plt.show()

# %%
ax = data['DIS'].hist(bins=30)

ax.set_xlabel('DIS')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра DIS (логнормальное распределение)')
plt.grid(True)
plt.show()

# %%
ax = data['RAD'].hist(bins=20)

ax.set_xlabel('RAD')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра RAD')
plt.grid(True)
plt.show()

# %%
ax = data['TAX'].hist(bins=20)

ax.set_xlabel('TAX')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра TAX')
plt.grid(True)
plt.show()

# %%
ax = data['PTRATIO'].hist(bins=20)

ax.set_xlabel('PTRATIO')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра PTRATIO')
plt.grid(True)
plt.show()

# %%
ax = data['B'].hist(bins=10)

ax.set_xlabel('B')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра B')
plt.grid(True)
plt.show()

# %%
ax = data['LSTAT'].hist(bins=15)

ax.set_xlabel('LSTAT')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра LSTAT (биноминальное распределение)')
plt.grid(True)
plt.show()

# %%
ax = data['MEDV'].hist(bins=15)

ax.set_xlabel('MEDV')
ax.set_ylabel('frequency')
ax.set_title('Частотный график для параметра MEDV (распределение Пуассона)')
plt.grid(True)
plt.show()

# %% [markdown]
# **Задача:** построить матрицу корреляций для данной таблицы и выбрать максимально коррелирующий атрибут (несколько атрибутов) с ценой на дома (MEDV атрибут).

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.1) #data.corr()-->матрица корреляций
# gcf() - получение текущей фигуры
fig=plt.gcf()
# set_size_inches() - установить размер фигуры
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# **C MEDV коррелируют максимальным образом 2 атрибута (хотя на мой взгляд корреляция в 0,7 недостаточна): RM (0.7) и LSTAT (отрицательная корреляция -0,74).**

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
medv = data['MEDV']
rm = data['RM']
# параметр fit_reg - строит линию регрессии для двух выборок
sns.regplot(x= medv, y=rm, data=data, fit_reg=True)
plt.xlabel('Стоимость жилья')
plt.ylabel('Количество комнат')
plt.title('Корреляционная зависимость двух выборок')
plt.grid(False)
plt.show()

# %%
medv = np.array(medv).reshape(-1,1)
rm = np.array(rm).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    medv,
    rm,
    test_size = 0.2
)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_y = model.predict(X_test)

# %%
print(mean_squared_error(predicted_y, y_test))
print(mean_absolute_error(predicted_y, y_test))
# Out:
# 0.2833501485956319
# 0.33624422313241625

# %% [markdown]
# ## В лекционном ноутбуке цифры 646 и 21 соответственно, и написано, что точность на тестовых данных 51%. Как мы это поняли?
#
# ## И второе, $x = np.linspace(0, 60, 1000)$  создает точки для предсказаний, но, как я понимаю, эти точки тестовыми ине являются, а всего лишь строят прямую регрессии? Поправьте меня

# %%
plt.xlabel('medv')
plt.ylabel('rm')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(0, 60, 1000)
# Посчитаем предсказанные значения
# y = kx + b
# k = model.coef_
# b = model.intercept_
y = model.coef_*x + model.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(X_train, y_train, 'r.')
plt.plot(X_test, y_test, 'go')
plt.xlim(0,60)
plt.ylim(0,10)
plt.legend(['Прямая линейной регрессии', 'Тренировочные данные', 'Тестовые данные'])
plt.show()

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %% [markdown]
# ## Можно подробнее про матрицу ковариации попарно? Я не уверена, что это то, как я сделала

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data_hap=pd.read_csv(url)
data_hap.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %% [markdown]
# **Матрица ковариаций попарно на примере трех столбцов**

# %%
data_hap[['Ladder', 'SD of Ladder']].cov()
# Out:
#                   Ladder  SD of Ladder
# Ladder        2041.00000    1100.83871
# SD of Ladder  1100.83871    2041.00000

# %%
data_hap[['SD of Ladder', 'Positive affect']].cov()
# Out:
#                  SD of Ladder  Positive affect
# SD of Ladder      2041.000000       173.694805
# Positive affect    173.694805      2015.000000

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop).

# %%
data_hap.loc[pd.isnull(data_hap['Country (region)']), :]
# Out:
# Empty DataFrame
# Columns: [Country (region), Ladder, SD of Ladder, Positive affect, Negative affect, Social support, Freedom, Corruption, Generosity, Log of GDP
# per capita, Healthy life
# expectancy]
# Index: []

# %% [markdown]
# Вывод - пустых значений нет.

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
country = data_hap['Country (region)'].unique()
#country
len(country)
# Out:
# 156

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %%
np.round_(data_hap.corr(), decimals=2)
# Out:
#                           Ladder  SD of Ladder  Positive affect  \
# Ladder                      1.00          0.54             0.49
# SD of Ladder                0.54          1.00             0.09
# Positive affect             0.49          0.09             1.00
# Negative affect             0.52          0.62             0.39
# Social support              0.82          0.60             0.39
# Freedom                     0.55          0.25             0.68
# Corruption                  0.19          0.26             0.21
# Generosity                  0.50          0.39             0.35
# Log of GDP\nper capita      0.81          0.63             0.30
# Healthy life\nexpectancy    0.82          0.61             0.33
#
#                           Negative affect  Social support  Freedom  \
# Ladder                               0.52            0.82     0.55
# SD of Ladder                         0.62            0.60     0.25
# ...

# %% [markdown]
# Хорошая корреляция наблюдается между показателем удовлетворенности жизнью и соц.поддержкой, ВВП и пролдолжительностью жизни. В остальном показатели можно назвать слабо зависимыми.

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
# вероятность выпадения каждой стороны кубика - 1/6 или 16%. Ниже. представлен график вероятности выпадения 
# одной стороны игрального кубика 10 раз

data_binom = stats.binom.rvs(n=10,p=0.166, size=1000)

# %%
ax = sns.distplot(data_binom,
                  kde=False,
                  color='blue')
ax.set(xlabel='Биноминальное распределение', ylabel='Частота (плотность)')
# Out:
# [Text(0, 0.5, 'Частота (плотность)'),
#  Text(0.5, 0, 'Биноминальное распределение')]

# %% [markdown]
# Смоделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %% [markdown]
# ## и вот здесь возник затык. ЦПТ применима только к равномерном распределению, а у нас в первом случае получается биноминальное.
